# %% [markdown]
# **Consider the following Python dictionary data and Python list labels:**
#
# **data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'],
#         'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4],
#         'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}**
#
# **labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']**

# %% [markdown]
# **1. Create a DataFrame birds from this dictionary data which has the index labels.**

# %%
import pandas as pd
import numpy as np

# Create a dictionary
data = {
    'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'],
    'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4],
    'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2],
    'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']
}

#create a list
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
# Create a DataFrame from the dictionary and list
bird_df4 = pd.DataFrame(data, index = labels)

# Print the DataFrame
bird_df4
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# **2. Display a summary of the basic information about birds DataFrame and its data.**

# %%
bird_df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birds     10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
bird_df4.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   4.437500   2.900000
# std    2.007797   0.875595
# min    1.500000   2.000000
# 25%    3.375000   2.000000
# 50%    4.000000   3.000000
# 75%    5.625000   3.750000
# max    8.000000   4.000000

# %% [markdown]
# **3. Print the first 2 rows of the birds dataframe**

# %%
bird_df4.head(2)
# Out:
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# b  Cranes  4.0       4      yes

# %% [markdown]
# **4. Print all the rows with only 'birds' and 'age' columns from the dataframe**

# %%
bird_df4[['birds', 'age']]
# Out:
#         birds  age
# a      Cranes  3.5
# b      Cranes  4.0
# c     plovers  1.5
# d  spoonbills  NaN
# e  spoonbills  6.0
# f      Cranes  3.0
# g     plovers  5.5
# h      Cranes  NaN
# i  spoonbills  8.0
# j  spoonbills  4.0

# %%
bird_df4[bird_df4.columns[0:2]]
# Out:
#         birds  age
# a      Cranes  3.5
# b      Cranes  4.0
# c     plovers  1.5
# d  spoonbills  NaN
# e  spoonbills  6.0
# f      Cranes  3.0
# g     plovers  5.5
# h      Cranes  NaN
# i  spoonbills  8.0
# j  spoonbills  4.0

# %% [markdown]
# **5. select [2, 3, 7] rows and in columns ['birds', 'age', 'visits']**

# %%
bird_df4.iloc[[2,3,7],[0,1,2]]
# Out:
#         birds  age  visits
# c     plovers  1.5       3
# d  spoonbills  NaN       4
# h      Cranes  NaN       2

# %%
bird_df4.iloc[2:7,0:3]
# Out:
#         birds  age  visits
# c     plovers  1.5       3
# d  spoonbills  NaN       4
# e  spoonbills  6.0       3
# f      Cranes  3.0       4
# g     plovers  5.5       2

# %% [markdown]
# **6. select the rows where the number of visits is less than 4**

# %%
bird_df4[bird_df4['visits'] < 4]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# **7. select the rows with columns ['birds', 'visits'] where the age is missing i.e NaN**

# %%
bird_df4[['birds','visits']][bird_df4['age'].isna()]
# Out:
#         birds  visits
# d  spoonbills       4
# h      Cranes       2

# %%
bird_df4[['birds','visits']][bird_df4['age'].isna()][bird_df4['visits'] == 4]
# Out:
# C:\Users\cm535\AppData\Local\Temp\ipykernel_19648\3438878973.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bird_df4[['birds','visits']][bird_df4['age'].isna()][bird_df4['visits'] == 4]
#         birds  visits
# d  spoonbills       4

# %%
bird_df4[['birds','visits']][bird_df4['visits'] < 4]
# Out:
#         birds  visits
# a      Cranes       2
# c     plovers       3
# e  spoonbills       3
# g     plovers       2
# h      Cranes       2
# i  spoonbills       3
# j  spoonbills       2

# %% [markdown]
# **8. Select the rows where the birds is a Cranes and the age is less than 4**

# %%
bird_df4[(bird_df4['age'] < 4) & (bird_df4['birds'] == 'Cranes')]
# Out:
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# f  Cranes  3.0       4       no

# %% [markdown]
# **9. Select the rows the age is between 2 and 4(inclusive)**

# %%
bird_df4[(bird_df4['age'] >= 2) & (bird_df4['age'] <= 4)]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# f      Cranes  3.0       4       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# **10. Find the total number of visits of the bird Cranes**

# %%
bird_df4[['birds','visits']]
# Out:
#         birds  visits
# a      Cranes       2
# b      Cranes       4
# c     plovers       3
# d  spoonbills       4
# e  spoonbills       3
# f      Cranes       4
# g     plovers       2
# h      Cranes       2
# i  spoonbills       3
# j  spoonbills       2

# %%
bird_df4[['birds','visits']][bird_df4['birds'] == 'Cranes']
# Out:
#     birds  visits
# a  Cranes       2
# b  Cranes       4
# f  Cranes       4
# h  Cranes       2

# %%
bird_df4[['birds','visits']][bird_df4['birds'] == 'Cranes'].sum()
# Out:
# birds     CranesCranesCranesCranes
# visits                          12
# dtype: object

# %% [markdown]
# **11. Calculate the mean age for each different birds in dataframe.**

# %%
bird_df4.groupby('birds').mean()
# Out:
#             age  visits
# birds
# Cranes      3.5     3.0
# plovers     3.5     2.5
# spoonbills  6.0     3.0

# %%
bird_df4.groupby('birds')['age'].mean()
# Out:
# birds
# Cranes        3.5
# plovers       3.5
# spoonbills    6.0
# Name: age, dtype: float64

# %% [markdown]
# **12. Append a new row 'k' to dataframe with your choice of values for each column. Then delete that row to return the original DataFrame.**

# %%
bird_df4
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
bird_df4.loc['k'] = ['Parrot', 10, 4, 'yes']
bird_df4.loc[10] = ['Parrot', 10, 4, 'yes']
bird_df4
# Out:
#          birds   age  visits priority
# a       Cranes   3.5       2      yes
# b       Cranes   4.0       4      yes
# c      plovers   1.5       3       no
# d   spoonbills   NaN       4      yes
# e   spoonbills   6.0       3       no
# f       Cranes   3.0       4       no
# g      plovers   5.5       2       no
# h       Cranes   NaN       2      yes
# i   spoonbills   8.0       3       no
# j   spoonbills   4.0       2       no
# k       Parrot  10.0       4      yes
# 10      Parrot  10.0       4      yes

# %%
bird_df4.drop(10,axis=0,inplace=True)
bird_df4
# Out:
#         birds   age  visits priority
# a      Cranes   3.5       2      yes
# b      Cranes   4.0       4      yes
# c     plovers   1.5       3       no
# d  spoonbills   NaN       4      yes
# e  spoonbills   6.0       3       no
# f      Cranes   3.0       4       no
# g     plovers   5.5       2       no
# h      Cranes   NaN       2      yes
# i  spoonbills   8.0       3       no
# j  spoonbills   4.0       2       no
# k      Parrot  10.0       4      yes

# %%
bird_df4.drop('k',axis=0,inplace=True)
bird_df4
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# **13. Find the number of each type of birds in dataframe (Counts)**

# %%
bird_df4.groupby('birds')['birds'].count()
# Out:
# birds
# Cranes        4
# plovers       2
# spoonbills    4
# Name: birds, dtype: int64

# %% [markdown]
# **14. Sort dataframe (birds) first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order.**

# %%
bird_df4.sort_values(by='age',ascending=False)
# Out:
#         birds  age  visits priority
# i  spoonbills  8.0       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# b      Cranes  4.0       4      yes
# j  spoonbills  4.0       2       no
# a      Cranes  3.5       2      yes
# f      Cranes  3.0       4       no
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# h      Cranes  NaN       2      yes

# %%
bird_df4.sort_values(by='visits',ascending=True)
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# j  spoonbills  4.0       2       no
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# i  spoonbills  8.0       3       no
# b      Cranes  4.0       4      yes
# d  spoonbills  NaN       4      yes
# f      Cranes  3.0       4       no

# %%
bird_df4.sort_values(by=['age','visits'], ascending=[False, True])
# Out:
#         birds  age  visits priority
# i  spoonbills  8.0       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# j  spoonbills  4.0       2       no
# b      Cranes  4.0       4      yes
# a      Cranes  3.5       2      yes
# f      Cranes  3.0       4       no
# c     plovers  1.5       3       no
# h      Cranes  NaN       2      yes
# d  spoonbills  NaN       4      yes

# %% [markdown]
# **15. Replace the priority column values with'yes' should be 1 and 'no' should be 0**

# %%
bird_df4
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
bird_df5 = bird_df4
bird_df6 = bird_df4
bird_df7 = bird_df4

# %% [markdown]
# Using NumPy.where() function

# %%
bird_df5['priority'] = np.where(bird_df5['priority'] == "yes", 1, 0)
bird_df5
# Out:
#         birds  age  visits  priority
# a      Cranes  3.5       2         1
# b      Cranes  4.0       4         1
# c     plovers  1.5       3         0
# d  spoonbills  NaN       4         1
# e  spoonbills  6.0       3         0
# f      Cranes  3.0       4         0
# g     plovers  5.5       2         0
# h      Cranes  NaN       2         1
# i  spoonbills  8.0       3         0
# j  spoonbills  4.0       2         0

# %% [markdown]
# using apply() and lambda

# %%
bird_df6['priority'] = bird_df6['priority'].apply(lambda x: 1 if x == 'male' else x)
bird_df6
# Out:
#         birds  age  visits  priority
# a      Cranes  3.5       2         1
# b      Cranes  4.0       4         1
# c     plovers  1.5       3         0
# d  spoonbills  NaN       4         1
# e  spoonbills  6.0       3         0
# f      Cranes  3.0       4         0
# g     plovers  5.5       2         0
# h      Cranes  NaN       2         1
# i  spoonbills  8.0       3         0
# j  spoonbills  4.0       2         0

# %% [markdown]
# **16. In the 'birds' column, change the 'Cranes' entries to 'trumpeters'.**

# %% [markdown]
# Using dataframe.loc[] Function

# %%
bird_df7.loc[bird_df7["birds"] == "Cranes", "birds"] = 'trumpeters'
bird_df7
# Out:
#         birds  age  visits  priority
# a  trumpeters  3.5       2         1
# b  trumpeters  4.0       4         1
# c     plovers  1.5       3         0
# d  spoonbills  NaN       4         1
# e  spoonbills  6.0       3         0
# f  trumpeters  3.0       4         0
# g     plovers  5.5       2         0
# h  trumpeters  NaN       2         1
# i  spoonbills  8.0       3         0
# j  spoonbills  4.0       2         0
